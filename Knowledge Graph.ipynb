# %% [markdown]
# # Knowledge Graph

# %%
import graphviz
# %load_ext gvmagic

# %%
# %%dot
#
# digraph {
#     rankdir=LR
#     node [fontname = "Arial", fontsize=6];
#     pf [label="Python\nFundamentals" tooltip="functions, classes, loops, if/then"]
#     pp [label="Basic\nPython\nPerformance"]
#     adv_pp [label="Advanced\nPython\nPerformance"]
#     bg [label="Basic Game\nInfrastructure\nw/Tic-Tac-Toe"]
#     game_theory [label="Game Theory\nPrimer"]
#     mm_ttt [label="Min-Max for\nTic-Tac-Toe"]
#     q_table [label="Reinforcement\nLearning -\nQ Function (via tables)"]
#     nn_fundamentals [label="Neural Network\nFundamentals"]
#     tf_fundamentals [label="Tensor Flow Fundamentals"]
#     q_nn [label="Q Function\nvia Neural Netorks"]
#     better_ttt [label="Improving\n the Tic-Tac-Toe\nNetwork"]
#     reversi [label="Additional Games -\nReversi"]
#     _2048 [label="Additional Games -\n2048"]
#     analytical_2048 [label="Analytical Methods\nfor 2048"]
#     nn_2048 [label="Neural Networks\nfor 2048"]
#     analytical_vs_comp [label="Analytical vs.\nComputational Methods"]
#     sm [label="The Scientific Method"]
#     nn_math [label="Math for\nNeural Networks"]
#     ai_ml [label="AI/ML Survey"]
#     markov [label="Markov Chains"]
#     ab_pruning [label="&alpha;-&beta;\npruning"]
#     analytical_reversi [label="Anaytical Methods\nfor Reversi"]
#     interactive_play [label="Interactive\nGame Widget"]
#     nn_scratch [label="Building a\nNeural Network\nfrom Scratch"]
#     regression [label="Regression"]
#     reuse [label="Writing Reusable\nCode"]
#     recursion [label="Recursion"]
#
#
#     pf -> reuse -> bg
#     pf -> recursion
#     pf -> pp -> adv_pp
#     bg -> mm_ttt
#     game_theory -> mm_ttt
#
#     mm_ttt -> q_table
#     q_table -> q_nn
#     q_nn -> better_ttt
#     pp -> mm_ttt
#     bg -> reversi
#     bg -> _2048 -> analytical_2048
#     sm -> better_ttt
#     game_theory -> ab_pruning
#
#     analytical_2048 -> nn_2048
#     better_ttt -> nn_2048
#     tf_fundamentals -> q_nn
#     ai_ml -> nn_fundamentals
#     bg -> interactive_play
#     analytical_vs_comp -> nn_fundamentals
#     analytical_vs_comp -> regression
#     recursion -> mm_ttt
#
#     subgraph {
#         rank=0
#         nn_math -> nn_fundamentals
#         nn_fundamentals -> nn_scratch
#         nn_fundamentals -> tf_fundamentals
#     }
#
#     markov -> analytical_2048
#     ab_pruning -> analytical_reversi
#     reversi -> analytical_reversi
#
#     subgraph cluster_nn {
#         label="Core Reinforcement Learning Path"
#         fontname=Arial
#         fontsize=10
#         bg
#         mm_ttt
#         q_table
#         q_nn
#         better_ttt
#     }
#
#     subgraph cluster_math {
#         label="Math Learning Path"
#         fontname=Arial
#         fontsize=10
#         nn_math
#         markov
#         analytical_vs_comp
#         regression
#         ab_pruning
#         game_theory
#     }
#
#     subgraph cluster_nn_fundamentals {
#         label="Neural Network Fundamentals Learning Path"
#         fontname=Arial
#         fontsize=10
#         ai_ml
#         nn_fundamentals
#         tf_fundamentals
#         nn_scratch
#     }
#
#
# }
